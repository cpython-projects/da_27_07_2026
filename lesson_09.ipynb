# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/da_27_07_2026/blob/main/lesson_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## SET
#
# *  mutable
# *  unordered
# *  no duplicates, hashable

# %%
x = {1, 1, 1, 1, 6, 7}
x
# Out:
# {1, 6, 7}

# %%
x = set('Python')
x
# Out:
# {'P', 'h', 'n', 'o', 't', 'y'}

# %%
x[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2002/3629782281.py in <cell line: 0>()
# ----> 1 x[0]
#
# TypeError: 'set' object is not subscriptable

# %%
for item in x:
  print(item)
# Out:
# n
# y
# o
# h
# t
# P

# %%
alice = {
    'vitalii', 'rubi', 'ihor', 'maksym'
}

bob = {
    'ivan', 'huawei', 'viktoriia', 'ihor', 'maksym'
}

# скільки людей будуть знати один одного?
mutual = alice & bob
print(mutual, len(mutual))
# Out:
# {'maksym', 'ihor'} 2

# %%
alice ^ bob
# Out:
# {'huawei', 'ivan', 'rubi', 'viktoriia', 'vitalii'}

# %%
file = open('test.txt', 'a')

file.write('*1\n')
file.write('*2\n')
file.write('*3\n')
file.write('*4\n')

file.close()

# %%
file = open('test.txt')
data = file.read()
data
# Out:
# '1\n2\n3\n4\n*1\n*2\n*3\n*4\n'

# %%
file = open('test.txt')
data = file.readlines()
data
# Out:
# ['1\n', '2\n', '3\n', '4\n', '*1\n', '*2\n', '*3\n', '*4\n']

# %%
file = open('test.txt')
for line in file:
  print(line)
# Out:
# 1
#
# 2
#
# 3
#
# 4
#
# *1
#
# *2
#
# *3
#
# *4

# %%
data = []
with open('ecommerce.csv') as file:
  header = file.readline().split(',')
  for line in file:
    line = line.split(',')
    data.append(dict(zip(header, line)))

# %%
res = {item['product_name'] for item in data}
print(res)
# Out:
# {'Smart Watch', 'Gaming Console', 'Wireless Mouse', 'Mechanical Keyboard', '"Monitor 27"""', 'Action Camera', '4K TV', 'E-reader', 'Tablet Mini', 'Air Purifier', 'Smartphone X', 'Graphics Tablet', 'Smart Bulb', 'Laptop Pro', 'Printer', 'Drone', 'Docking Station', 'Wireless Earbuds', 'Webcam', 'Bluetooth Speaker', 'Microphone', 'External SSD', 'NAS Drive', 'VR Headset', 'Fitness Tracker', 'Smart Plug', 'Projector', 'Robot Vacuum', 'DSLR Camera'}

# %%
import csv

# %%
file = open('ecommerce.csv')

# %%
data = csv.DictReader(file)

# %%
for row in data:
  print(row)
# Out:
# {'order_id': '1001', 'customer_id': 'C101', 'order_date': '2023-01-15', 'product_id': 'P001', 'product_name': 'Smartphone X', 'category': 'Electronics', 'price': '599.99', 'quantity': '1', 'weight': '0.5kg', 'discount': '0.1', 'shipping_cost': '5.99', 'payment_method': 'Credit Card', 'delivery_status': 'Delivered', 'customer_city': 'New York', 'customer_state': 'NY', 'customer_country': 'USA', 'return_requested': '0', 'review_score': '5.0', 'days_to_deliver': '3.0'}
# {'order_id': '1002', 'customer_id': 'C102', 'order_date': '2023-01-16', 'product_id': 'P002', 'product_name': 'Laptop Pro', 'category': 'Electronics', 'price': '1299.99', 'quantity': '1', 'weight': '2.2kg', 'discount': '0.15', 'shipping_cost': '12.99', 'payment_method': 'paypal', 'delivery_status': 'Delivered', 'customer_city': 'los angeles', 'customer_state': 'CA', 'customer_country': 'USA', 'return_requested': '1', 'review_score': '4.0', 'days_to_deliver': '5.0'}
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('ecommerce.csv')
df.category.unique()
# Out:
# array(['Electronics', 'Smart Home'], dtype=object)

# %%
df.head(10)
# Out:
#    order_id customer_id  order_date product_id       product_name  \
# 0      1001        C101  2023-01-15       P001       Smartphone X
# 1      1002        C102  2023-01-16       P002         Laptop Pro
# 2      1003        C103  2023-01-17       P003   Wireless Earbuds
# 3      1004        C104  2023-01-18       P004        Smart Watch
# 4      1005        C105  2023-01-19       P005        Tablet Mini
# 5      1006        C106  2023-01-20       P006  Bluetooth Speaker
# 6      1007        C107  2023-01-21       P007    Fitness Tracker
# 7      1008        C108  2023-01-22       P008              4K TV
# 8      1009        C109  2023-01-23       P009     Gaming Console
# 9      1010        C110  2023-01-24       P010        DSLR Camera
#
#       category    price  quantity  weight  discount  shipping_cost  \
# 0  Electronics   599.99         1   0.5kg      0.10           5.99
# 1  Electronics  1299.99         1   2.2kg      0.15          12.99
# ...
